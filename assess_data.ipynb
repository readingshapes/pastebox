# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
# %matplotlib inline

# %%
from IPython.display import display, HTML

display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
# Out:
# <style>.output_result { max-width:100% !important; }</style>

# %%
# function to quickly assess a dataframe's completeness and basic descriptive statistics
# makes a distinction between missing (na) and emtpy strings, strings that are just whitespace, etc.
# returns counts for strings; gregates for numeric columns
# optional argument styles output dataframe with color bars

from collections import defaultdict

def assess_data(df, highlight_color):

    np.seterr(divide='ignore', invalid='ignore')
    all_dict = defaultdict(list) 
    str_cols = df.select_dtypes(include=[object]).columns.tolist()
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()

    for i in df[str_cols]:
        str_is_null = df[i].isna().sum()
        str_spaces = df[i].str.contains(r'^\s{1,}$').sum()
        str_empty_string = len(df.loc[df[i]==''])

        string_dict = {'str_is_null' : str_is_null, 'str_spaces' : str_spaces
                       , 'str_empty_string' : str_empty_string}
        all_dict[i].append(string_dict)
    
    for i in df[num_cols]:
        num_is_null = df[i].isna().sum()
        num_mean_val = df[i].mean()
        num_min_val = df[i].min()
        num_max_val = df[i].max()
        num_unique_count = df[i].nunique()

        num_dict = {'num_is_null' : num_is_null, 'num_mean_val' : num_mean_val, 'num_min_val' : num_min_val
                    , 'num_max_val' : num_max_val, 'num_unique_count' : num_unique_count}
        all_dict[i].append(num_dict)

    x = pd.DataFrame(data=all_dict).T
    x.columns = ['column_summary']
    x.index.name = 'column_name'
    summarized_df = pd.json_normalize(x['column_summary'])
    summarized_df.index = x.index
    summarized_df = summarized_df.fillna(0)
    
    return summarized_df.style.format(precision=1, thousands=",").bar(color=highlight_color)

# %%
# test

mything = {'food' : ['sandwich', 'cereal', 'pizza', 'ice cream', np.nan, "   ", "  ", np.nan],
'animals' : ['puppy', 'kitty', 'dolphin', 'penguin', np.nan, '', '', np.nan],
'numbers' : [1, 2, np.nan, 0, 5, 6, np.nan, np.nan],
'pcts' : [.4, .02, 1.0, np.nan, .2, .0002, .66, np.nan]
}

my_df = pd.DataFrame(data=mything)

# %%
assess_data(my_df, '')
# Out:
# <style type="text/css">
# #T_358e1_row0_col0, #T_358e1_row0_col1, #T_358e1_row1_col0, #T_358e1_row1_col2, #T_358e1_row2_col3, #T_358e1_row2_col4, #T_358e1_row2_col6, #T_358e1_row3_col5, #T_358e1_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg,  100.0%, transparent 100.0%);
# }
# #T_358e1_row0_col2, #T_358e1_row0_col3, #T_358e1_row0_col4, #T_358e1_row0_col5, #T_358e1_row0_col6, #T_358e1_row0_col7, #T_358e1_row1_col1, #T_358e1_row1_col3, #T_358e1_row1_col4, #T_358e1_row1_col5, #T_358e1_row1_col6, #T_358e1_row1_col7, #T_358e1_row2_col0, #T_358e1_row2_col1, #T_358e1_row2_col2, #T_358e1_row2_col5, #T_358e1_row3_col0, #T_358e1_row3_col1, #T_358e1_row3_col2 {
#   width: 10em;
# }
# #T_358e1_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg,  83.3%, transparent 83.3%);
# }
# #T_358e1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg,  66.7%, transparent 66.7%);
# }
# #T_358e1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg,  13.6%, transparent 13.6%);
# }
# #T_358e1_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg,  16.7%, transparent 16.7%);
# }
# </style>
# <table id="T_358e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_358e1_level0_col0" class="col_heading level0 col0" >str_is_null</th>
#       <th id="T_358e1_level0_col1" class="col_heading level0 col1" >str_spaces</th>
#       <th id="T_358e1_level0_col2" class="col_heading level0 col2" >str_empty_string</th>
#       <th id="T_358e1_level0_col3" class="col_heading level0 col3" >num_is_null</th>
#       <th id="T_358e1_level0_col4" class="col_heading level0 col4" >num_mean_val</th>
#       <th id="T_358e1_level0_col5" class="col_heading level0 col5" >num_min_val</th>
#       <th id="T_358e1_level0_col6" class="col_heading level0 col6" >num_max_val</th>
#       <th id="T_358e1_level0_col7" class="col_heading level0 col7" >num_unique_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_358e1_level0_row0" class="row_heading level0 row0" >food</th>
#       <td id="T_358e1_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_358e1_row0_col1" class="data row0 col1" >2.0</td>
#       <td id="T_358e1_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_358e1_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_358e1_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_358e1_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_358e1_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_358e1_row0_col7" class="data row0 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_358e1_level0_row1" class="row_heading level0 row1" >animals</th>
#       <td id="T_358e1_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_358e1_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_358e1_row1_col2" class="data row1 col2" >2.0</td>
#       <td id="T_358e1_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_358e1_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_358e1_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_358e1_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_358e1_row1_col7" class="data row1 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_358e1_level0_row2" class="row_heading level0 row2" >numbers</th>
#       <td id="T_358e1_row2_col0" class="data row2 col0" >0.0</td>
#       <td id="T_358e1_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_358e1_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_358e1_row2_col3" class="data row2 col3" >3.0</td>
#       <td id="T_358e1_row2_col4" class="data row2 col4" >2.8</td>
#       <td id="T_358e1_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_358e1_row2_col6" class="data row2 col6" >6.0</td>
#       <td id="T_358e1_row2_col7" class="data row2 col7" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_358e1_level0_row3" class="row_heading level0 row3" >pcts</th>
#       <td id="T_358e1_row3_col0" class="data row3 col0" >0.0</td>
#       <td id="T_358e1_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_358e1_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_358e1_row3_col3" class="data row3 col3" >2.0</td>
#       <td id="T_358e1_row3_col4" class="data row3 col4" >0.4</td>
#       <td id="T_358e1_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_358e1_row3_col6" class="data row3 col6" >1.0</td>
#       <td id="T_358e1_row3_col7" class="data row3 col7" >6.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
my_df.describe(include='all') # compare output of assess_data to output of 'describe'
# Out:
#             food animals   numbers      pcts
# count          6       6  5.000000  6.000000
# unique         6       5       NaN       NaN
# top     sandwich               NaN       NaN
# freq           1       2       NaN       NaN
# mean         NaN     NaN  2.800000  0.380033
# std          NaN     NaN  2.588436  0.392288
# min          NaN     NaN  0.000000  0.000200
# 25%          NaN     NaN  1.000000  0.065000
# 50%          NaN     NaN  2.000000  0.300000
# 75%          NaN     NaN  5.000000  0.595000
# max          NaN     NaN  6.000000  1.000000

# %%
# test on local files

divrates = pd.read_csv('qualDivRates.csv')
nearestpost = pd.read_csv('NearestPostCheck.csv')
rr_denominator = pd.read_csv('rr_denominator.csv')
ugh = pd.read_csv('ugh.csv')
ugradenroll = pd.read_csv('ugradenroll.csv')

# %%
assess_data(divrates, 'blue')
# Out:
# <style type="text/css">
# #T_f1f79_row0_col0, #T_f1f79_row0_col1, #T_f1f79_row0_col2, #T_f1f79_row0_col3, #T_f1f79_row0_col4, #T_f1f79_row0_col5, #T_f1f79_row0_col6, #T_f1f79_row0_col7, #T_f1f79_row1_col0, #T_f1f79_row1_col1, #T_f1f79_row1_col2, #T_f1f79_row1_col3, #T_f1f79_row2_col0, #T_f1f79_row2_col1, #T_f1f79_row2_col2, #T_f1f79_row3_col0, #T_f1f79_row3_col1, #T_f1f79_row3_col2 {
#   width: 10em;
# }
# #T_f1f79_row1_col4, #T_f1f79_row1_col5, #T_f1f79_row1_col6, #T_f1f79_row1_col7, #T_f1f79_row2_col3, #T_f1f79_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 100.0%, transparent 100.0%);
# }
# #T_f1f79_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 34.1%, transparent 34.1%);
# }
# #T_f1f79_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 37.9%, transparent 37.9%);
# }
# #T_f1f79_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 34.6%, transparent 34.6%);
# }
# #T_f1f79_row2_col7, #T_f1f79_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 91.7%, transparent 91.7%);
# }
# #T_f1f79_row3_col4, #T_f1f79_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 0.0%, transparent 0.0%);
# }
# #T_f1f79_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 0.1%, transparent 0.1%);
# }
# </style>
# <table id="T_f1f79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1f79_level0_col0" class="col_heading level0 col0" >str_is_null</th>
#       <th id="T_f1f79_level0_col1" class="col_heading level0 col1" >str_spaces</th>
#       <th id="T_f1f79_level0_col2" class="col_heading level0 col2" >str_empty_string</th>
#       <th id="T_f1f79_level0_col3" class="col_heading level0 col3" >num_is_null</th>
#       <th id="T_f1f79_level0_col4" class="col_heading level0 col4" >num_mean_val</th>
#       <th id="T_f1f79_level0_col5" class="col_heading level0 col5" >num_min_val</th>
#       <th id="T_f1f79_level0_col6" class="col_heading level0 col6" >num_max_val</th>
#       <th id="T_f1f79_level0_col7" class="col_heading level0 col7" >num_unique_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1f79_level0_row0" class="row_heading level0 row0" >divNm</th>
#       <td id="T_f1f79_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_f1f79_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_f1f79_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_f1f79_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_f1f79_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_f1f79_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_f1f79_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_f1f79_row0_col7" class="data row0 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f1f79_level0_row1" class="row_heading level0 row1" >invv</th>
#       <td id="T_f1f79_row1_col0" class="data row1 col0" >0.0</td>
#       <td id="T_f1f79_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_f1f79_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_f1f79_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_f1f79_row1_col4" class="data row1 col4" >1,466.8</td>
#       <td id="T_f1f79_row1_col5" class="data row1 col5" >427.0</td>
#       <td id="T_f1f79_row1_col6" class="data row1 col6" >4,796.0</td>
#       <td id="T_f1f79_row1_col7" class="data row1 col7" >12.0</td>
#     </tr>
#     <tr>
#       <th id="T_f1f79_level0_row2" class="row_heading level0 row2" >respv</th>
#       <td id="T_f1f79_row2_col0" class="data row2 col0" >0.0</td>
#       <td id="T_f1f79_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_f1f79_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_f1f79_row2_col3" class="data row2 col3" >1.0</td>
#       <td id="T_f1f79_row2_col4" class="data row2 col4" >499.8</td>
#       <td id="T_f1f79_row2_col5" class="data row2 col5" >162.0</td>
#       <td id="T_f1f79_row2_col6" class="data row2 col6" >1,658.0</td>
#       <td id="T_f1f79_row2_col7" class="data row2 col7" >11.0</td>
#     </tr>
#     <tr>
#       <th id="T_f1f79_level0_row3" class="row_heading level0 row3" >divRR</th>
#       <td id="T_f1f79_row3_col0" class="data row3 col0" >0.0</td>
#       <td id="T_f1f79_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_f1f79_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_f1f79_row3_col3" class="data row3 col3" >1.0</td>
#       <td id="T_f1f79_row3_col4" class="data row3 col4" >0.3</td>
#       <td id="T_f1f79_row3_col5" class="data row3 col5" >0.3</td>
#       <td id="T_f1f79_row3_col6" class="data row3 col6" >0.5</td>
#       <td id="T_f1f79_row3_col7" class="data row3 col7" >11.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
assess_data(nearestpost, 'red')
# Out:
# <style type="text/css">
# #T_d0180_row0_col0, #T_d0180_row0_col1, #T_d0180_row0_col2, #T_d0180_row0_col3, #T_d0180_row0_col4, #T_d0180_row0_col5, #T_d0180_row0_col6, #T_d0180_row0_col7, #T_d0180_row1_col1, #T_d0180_row1_col2, #T_d0180_row1_col3, #T_d0180_row1_col4, #T_d0180_row1_col5, #T_d0180_row1_col6, #T_d0180_row1_col7, #T_d0180_row2_col1, #T_d0180_row2_col2, #T_d0180_row2_col3, #T_d0180_row2_col4, #T_d0180_row2_col5, #T_d0180_row2_col6, #T_d0180_row2_col7, #T_d0180_row3_col1, #T_d0180_row3_col2, #T_d0180_row3_col3, #T_d0180_row3_col4, #T_d0180_row3_col5, #T_d0180_row3_col6, #T_d0180_row3_col7, #T_d0180_row4_col0, #T_d0180_row4_col1, #T_d0180_row4_col2, #T_d0180_row4_col3, #T_d0180_row4_col4, #T_d0180_row4_col5, #T_d0180_row4_col6, #T_d0180_row4_col7, #T_d0180_row5_col0, #T_d0180_row5_col1, #T_d0180_row5_col2, #T_d0180_row5_col3, #T_d0180_row5_col4, #T_d0180_row5_col5, #T_d0180_row5_col6, #T_d0180_row5_col7, #T_d0180_row6_col0, #T_d0180_row6_col1, #T_d0180_row6_col2, #T_d0180_row6_col3, #T_d0180_row6_col5, #T_d0180_row7_col0, #T_d0180_row7_col1, #T_d0180_row7_col2 {
#   width: 10em;
# }
# #T_d0180_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 92.9%, transparent 92.9%);
# }
# #T_d0180_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 92.6%, transparent 92.6%);
# }
# #T_d0180_row3_col0, #T_d0180_row7_col3, #T_d0180_row7_col4, #T_d0180_row7_col5, #T_d0180_row7_col6, #T_d0180_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# #T_d0180_row6_col4, #T_d0180_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, red 0.0%, transparent 0.0%);
# }
# #T_d0180_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, red 66.7%, transparent 66.7%);
# }
# </style>
# <table id="T_d0180">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0180_level0_col0" class="col_heading level0 col0" >str_is_null</th>
#       <th id="T_d0180_level0_col1" class="col_heading level0 col1" >str_spaces</th>
#       <th id="T_d0180_level0_col2" class="col_heading level0 col2" >str_empty_string</th>
#       <th id="T_d0180_level0_col3" class="col_heading level0 col3" >num_is_null</th>
#       <th id="T_d0180_level0_col4" class="col_heading level0 col4" >num_mean_val</th>
#       <th id="T_d0180_level0_col5" class="col_heading level0 col5" >num_min_val</th>
#       <th id="T_d0180_level0_col6" class="col_heading level0 col6" >num_max_val</th>
#       <th id="T_d0180_level0_col7" class="col_heading level0 col7" >num_unique_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0180_level0_row0" class="row_heading level0 row0" >nearest</th>
#       <td id="T_d0180_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_d0180_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_d0180_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_d0180_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_d0180_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_d0180_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_d0180_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_d0180_row0_col7" class="data row0 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row1" class="row_heading level0 row1" >Term</th>
#       <td id="T_d0180_row1_col0" class="data row1 col0" >643.0</td>
#       <td id="T_d0180_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_d0180_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_d0180_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_d0180_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_d0180_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_d0180_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_d0180_row1_col7" class="data row1 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row2" class="row_heading level0 row2" >entrytype</th>
#       <td id="T_d0180_row2_col0" class="data row2 col0" >641.0</td>
#       <td id="T_d0180_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_d0180_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_d0180_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_d0180_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_d0180_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_d0180_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_d0180_row2_col7" class="data row2 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row3" class="row_heading level0 row3" >Residency</th>
#       <td id="T_d0180_row3_col0" class="data row3 col0" >692.0</td>
#       <td id="T_d0180_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_d0180_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_d0180_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_d0180_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_d0180_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_d0180_row3_col6" class="data row3 col6" >0.0</td>
#       <td id="T_d0180_row3_col7" class="data row3 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row4" class="row_heading level0 row4" >sirdt</th>
#       <td id="T_d0180_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_d0180_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_d0180_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_d0180_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_d0180_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_d0180_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_d0180_row4_col6" class="data row4 col6" >0.0</td>
#       <td id="T_d0180_row4_col7" class="data row4 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row5" class="row_heading level0 row5" >PostSet</th>
#       <td id="T_d0180_row5_col0" class="data row5 col0" >0.0</td>
#       <td id="T_d0180_row5_col1" class="data row5 col1" >0.0</td>
#       <td id="T_d0180_row5_col2" class="data row5 col2" >0.0</td>
#       <td id="T_d0180_row5_col3" class="data row5 col3" >0.0</td>
#       <td id="T_d0180_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_d0180_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_d0180_row5_col6" class="data row5 col6" >0.0</td>
#       <td id="T_d0180_row5_col7" class="data row5 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row6" class="row_heading level0 row6" >eversir</th>
#       <td id="T_d0180_row6_col0" class="data row6 col0" >0.0</td>
#       <td id="T_d0180_row6_col1" class="data row6 col1" >0.0</td>
#       <td id="T_d0180_row6_col2" class="data row6 col2" >0.0</td>
#       <td id="T_d0180_row6_col3" class="data row6 col3" >0.0</td>
#       <td id="T_d0180_row6_col4" class="data row6 col4" >1.0</td>
#       <td id="T_d0180_row6_col5" class="data row6 col5" >0.0</td>
#       <td id="T_d0180_row6_col6" class="data row6 col6" >1.0</td>
#       <td id="T_d0180_row6_col7" class="data row6 col7" >2.0</td>
#     </tr>
#     <tr>
#       <th id="T_d0180_level0_row7" class="row_heading level0 row7" >AcaYrAdj</th>
#       <td id="T_d0180_row7_col0" class="data row7 col0" >0.0</td>
#       <td id="T_d0180_row7_col1" class="data row7 col1" >0.0</td>
#       <td id="T_d0180_row7_col2" class="data row7 col2" >0.0</td>
#       <td id="T_d0180_row7_col3" class="data row7 col3" >643.0</td>
#       <td id="T_d0180_row7_col4" class="data row7 col4" >2,018.0</td>
#       <td id="T_d0180_row7_col5" class="data row7 col5" >2,017.0</td>
#       <td id="T_d0180_row7_col6" class="data row7 col6" >2,019.0</td>
#       <td id="T_d0180_row7_col7" class="data row7 col7" >

# %%
assess_data(rr_denominator, 'green')
# Out:
# <style type="text/css">
# #T_753e6_row0_col0, #T_753e6_row0_col1, #T_753e6_row0_col2, #T_753e6_row0_col3, #T_753e6_row0_col4, #T_753e6_row0_col5, #T_753e6_row0_col6, #T_753e6_row0_col7, #T_753e6_row1_col0, #T_753e6_row1_col1, #T_753e6_row1_col2, #T_753e6_row1_col3, #T_753e6_row1_col4, #T_753e6_row1_col5, #T_753e6_row1_col6, #T_753e6_row1_col7, #T_753e6_row2_col1, #T_753e6_row2_col2, #T_753e6_row2_col3, #T_753e6_row2_col4, #T_753e6_row2_col5, #T_753e6_row2_col6, #T_753e6_row2_col7, #T_753e6_row3_col0, #T_753e6_row3_col1, #T_753e6_row3_col2, #T_753e6_row3_col3, #T_753e6_row3_col4, #T_753e6_row3_col5, #T_753e6_row3_col6, #T_753e6_row3_col7, #T_753e6_row4_col0, #T_753e6_row4_col1, #T_753e6_row4_col2, #T_753e6_row4_col3, #T_753e6_row4_col4, #T_753e6_row4_col5, #T_753e6_row4_col6, #T_753e6_row4_col7, #T_753e6_row5_col1, #T_753e6_row5_col2, #T_753e6_row5_col3, #T_753e6_row5_col4, #T_753e6_row5_col5, #T_753e6_row5_col6, #T_753e6_row5_col7, #T_753e6_row6_col0, #T_753e6_row6_col1, #T_753e6_row6_col2, #T_753e6_row6_col3, #T_753e6_row6_col4, #T_753e6_row6_col5, #T_753e6_row6_col6, #T_753e6_row6_col7, #T_753e6_row7_col0, #T_753e6_row7_col1, #T_753e6_row7_col2, #T_753e6_row7_col3, #T_753e6_row7_col4, #T_753e6_row7_col5, #T_753e6_row7_col6, #T_753e6_row7_col7, #T_753e6_row8_col1, #T_753e6_row8_col2, #T_753e6_row8_col3, #T_753e6_row8_col4, #T_753e6_row8_col5, #T_753e6_row8_col6, #T_753e6_row8_col7, #T_753e6_row9_col1, #T_753e6_row9_col2, #T_753e6_row9_col3, #T_753e6_row9_col4, #T_753e6_row9_col5, #T_753e6_row9_col6, #T_753e6_row9_col7, #T_753e6_row10_col1, #T_753e6_row10_col2, #T_753e6_row10_col3, #T_753e6_row10_col4, #T_753e6_row10_col5, #T_753e6_row10_col6, #T_753e6_row10_col7, #T_753e6_row11_col1, #T_753e6_row11_col2, #T_753e6_row11_col3, #T_753e6_row11_col4, #T_753e6_row11_col5, #T_753e6_row11_col6, #T_753e6_row11_col7, #T_753e6_row12_col1, #T_753e6_row12_col2, #T_753e6_row12_col3, #T_753e6_row12_col4, #T_753e6_row12_col5, #T_753e6_row12_col6, #T_753e6_row12_col7, #T_753e6_row13_col1, #T_753e6_row13_col2, #T_753e6_row13_col3, #T_753e6_row13_col4, #T_753e6_row13_col5, #T_753e6_row13_col6, #T_753e6_row13_col7, #T_753e6_row14_col0, #T_753e6_row14_col1, #T_753e6_row14_col2, #T_753e6_row15_col0, #T_753e6_row15_col1, #T_753e6_row15_col2, #T_753e6_row15_col3, #T_753e6_row16_col0, #T_753e6_row16_col1, #T_753e6_row16_col2, #T_753e6_row16_col3, #T_753e6_row17_col0, #T_753e6_row17_col1, #T_753e6_row17_col2, #T_753e6_row18_col0, #T_753e6_row18_col1, #T_753e6_row18_col2, #T_753e6_row19_col0, #T_753e6_row19_col1, #T_753e6_row19_col2, #T_753e6_row20_col0, #T_753e6_row20_col1, #T_753e6_row20_col2, #T_753e6_row21_col0, #T_753e6_row21_col1, #T_753e6_row21_col2, #T_753e6_row21_col4, #T_753e6_row21_col5, #T_753e6_row21_col6, #T_753e6_row21_col7, #T_753e6_row22_col0, #T_753e6_row22_col1, #T_753e6_row22_col2, #T_753e6_row23_col0, #T_753e6_row23_col1, #T_753e6_row23_col2, #T_753e6_row24_col0, #T_753e6_row24_col1, #T_753e6_row24_col2, #T_753e6_row25_col0, #T_753e6_row25_col1, #T_753e6_row25_col2, #T_753e6_row25_col3, #T_753e6_row26_col0, #T_753e6_row26_col1, #T_753e6_row26_col2, #T_753e6_row26_col3, #T_753e6_row27_col0, #T_753e6_row27_col1, #T_753e6_row27_col2, #T_753e6_row28_col0, #T_753e6_row28_col1, #T_753e6_row28_col2, #T_753e6_row29_col0, #T_753e6_row29_col1, #T_753e6_row29_col2 {
#   width: 10em;
# }
# #T_753e6_row2_col0, #T_753e6_row5_col0, #T_753e6_row8_col0, #T_753e6_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 89.4%, transparent 89.4%);
# }
# #T_753e6_row10_col0, #T_753e6_row11_col0, #T_753e6_row12_col0, #T_753e6_row13_col0, #T_753e6_row21_col3, #T_753e6_row26_col4, #T_753e6_row26_col5, #T_753e6_row26_col6, #T_753e6_row26_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_753e6_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.4%, transparent 0.4%);
# }
# #T_753e6_row14_col4, #T_753e6_row14_col5, #T_753e6_row14_col6, #T_753e6_row15_col4, #T_753e6_row15_col5, #T_753e6_row15_col6, #T_753e6_row15_col7, #T_753e6_row16_col4, #T_753e6_row16_col5, #T_753e6_row16_col6, #T_753e6_row16_col7, #T_753e6_row17_col4, #T_753e6_row17_col6, #T_753e6_row18_col4, #T_753e6_row18_col5, #T_753e6_row18_col6, #T_753e6_row18_col7, #T_753e6_row19_col4, #T_753e6_row19_col5, #T_753e6_row19_col6, #T_753e6_row20_col4, #T_753e6_row20_col6, #T_753e6_row22_col4, #T_753e6_row22_col5, #T_753e6_row22_col6, #T_753e6_row22_col7, #T_753e6_row23_col4, #T_753e6_row23_col5, #T_753e6_row23_col6, #T_753e6_row24_col4, #T_753e6_row24_col6, #T_753e6_row25_col4, #T_753e6_row25_col5, #T_753e6_row25_col6, #T_753e6_row25_col7, #T_753e6_row27_col4, #T_753e6_row27_col5, #T_753e6_row27_col6, #T_753e6_row28_col4, #T_753e6_row28_col5, #T_753e6_row28_col6, #T_753e6_row29_col4, #T_753e6_row29_col5, #T_753e6_row29_col6, #T_753e6_row29_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.0%, transparent 0.0%);
# }
# #T_753e6_row14_col7, #T_753e6_row17_col3, #T_753e6_row23_col7, #T_753e6_row24_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.1%, transparent 0.1%);
# }
# #T_753e6_row17_col5, #T_753e6_row20_col5, #T_753e6_row28_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.3%, transparent 0.3%);
# }
# #T_753e6_row17_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.6%, transparent 0.6%);
# }
# #T_753e6_row18_col3, #T_753e6_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 89.1%, transparent 89.1%);
# }
# #T_753e6_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 89.7%, transparent 89.7%);
# }
# #T_753e6_row19_col7, #T_753e6_row20_col7, #T_753e6_row27_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, green 0.5%, transparent 0.5%);
# }
# #T_753e6_row22_col3, #T_753e6_row23_col3, #T_753e6_row24_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 99.7%, transparent 99.7%);
# }
# #T_753e6_row24_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 1.0%, transparent 1.0%);
# }
# #T_753e6_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 60.6%, transparent 60.6%);
# }
# #T_753e6_row28_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 96.4%, transparent 96.4%);
# }
# #T_753e6_row29_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, green 99.9%, transparent 99.9%);
# }
# </style>
# <table id="T_753e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_753e6_level0_col0" class="col_heading level0 col0" >str_is_null</th>
#       <th id="T_753e6_level0_col1" class="col_heading level0 col1" >str_spaces</th>
#       <th id="T_753e6_level0_col2" class="col_heading level0 col2" >str_empty_string</th>
#       <th id="T_753e6_level0_col3" class="col_heading level0 col3" >num_is_null</th>
#       <th id="T_753e6_level0_col4" class="col_heading level0 col4" >num_mean_val</th>
#       <th id="T_753e6_level0_col5" class="col_heading level0 col5" >num_min_val</th>
#       <th id="T_753e6_level0_col6" class="col_heading level0 col6" >num_max_val</th>
#       <th id="T_753e6_level0_col7" class="col_heading level0 col7" >num_unique_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_753e6_level0_row0" class="row_heading level0 row0" >EVAL_MAJOR</th>
#       <td id="T_753e6_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_753e6_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_753e6_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_753e6_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_753e6_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_753e6_row0_col5" class="data

# %%
assess_data(ugh, 'blue')
# Out:
# <style type="text/css">
# #T_ee49a_row0_col0, #T_ee49a_row0_col1, #T_ee49a_row0_col2, #T_ee49a_row0_col3, #T_ee49a_row0_col4, #T_ee49a_row0_col5, #T_ee49a_row0_col6, #T_ee49a_row0_col7, #T_ee49a_row1_col0, #T_ee49a_row1_col1, #T_ee49a_row1_col2, #T_ee49a_row1_col3, #T_ee49a_row1_col4, #T_ee49a_row1_col5, #T_ee49a_row1_col6, #T_ee49a_row1_col7, #T_ee49a_row2_col0, #T_ee49a_row2_col1, #T_ee49a_row2_col2, #T_ee49a_row2_col3, #T_ee49a_row2_col4, #T_ee49a_row2_col5, #T_ee49a_row2_col6, #T_ee49a_row2_col7, #T_ee49a_row3_col0, #T_ee49a_row3_col1, #T_ee49a_row3_col2, #T_ee49a_row3_col3, #T_ee49a_row3_col4, #T_ee49a_row3_col5, #T_ee49a_row3_col6, #T_ee49a_row3_col7, #T_ee49a_row4_col0, #T_ee49a_row4_col1, #T_ee49a_row4_col2, #T_ee49a_row4_col3, #T_ee49a_row4_col4, #T_ee49a_row4_col5, #T_ee49a_row4_col6, #T_ee49a_row4_col7, #T_ee49a_row5_col0, #T_ee49a_row5_col1, #T_ee49a_row5_col2, #T_ee49a_row5_col3, #T_ee49a_row5_col4, #T_ee49a_row5_col5, #T_ee49a_row5_col6, #T_ee49a_row5_col7, #T_ee49a_row6_col0, #T_ee49a_row6_col1, #T_ee49a_row6_col2, #T_ee49a_row6_col3, #T_ee49a_row6_col4, #T_ee49a_row6_col5, #T_ee49a_row6_col6, #T_ee49a_row6_col7, #T_ee49a_row7_col1, #T_ee49a_row7_col2, #T_ee49a_row7_col3, #T_ee49a_row7_col4, #T_ee49a_row7_col5, #T_ee49a_row7_col6, #T_ee49a_row7_col7, #T_ee49a_row8_col0, #T_ee49a_row8_col1, #T_ee49a_row8_col2, #T_ee49a_row8_col3, #T_ee49a_row9_col0, #T_ee49a_row9_col1, #T_ee49a_row9_col2, #T_ee49a_row9_col4, #T_ee49a_row9_col5, #T_ee49a_row9_col6, #T_ee49a_row9_col7, #T_ee49a_row10_col0, #T_ee49a_row10_col1, #T_ee49a_row10_col2, #T_ee49a_row10_col4, #T_ee49a_row10_col5, #T_ee49a_row10_col6, #T_ee49a_row10_col7, #T_ee49a_row11_col0, #T_ee49a_row11_col1, #T_ee49a_row11_col2, #T_ee49a_row11_col3 {
#   width: 10em;
# }
# #T_ee49a_row7_col0, #T_ee49a_row8_col4, #T_ee49a_row8_col5, #T_ee49a_row8_col6, #T_ee49a_row8_col7, #T_ee49a_row9_col3, #T_ee49a_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 100.0%, transparent 100.0%);
# }
# #T_ee49a_row11_col4, #T_ee49a_row11_col5, #T_ee49a_row11_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 0.0%, transparent 0.0%);
# }
# #T_ee49a_row11_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 0.3%, transparent 0.3%);
# }
# </style>
# <table id="T_ee49a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee49a_level0_col0" class="col_heading level0 col0" >str_is_null</th>
#       <th id="T_ee49a_level0_col1" class="col_heading level0 col1" >str_spaces</th>
#       <th id="T_ee49a_level0_col2" class="col_heading level0 col2" >str_empty_string</th>
#       <th id="T_ee49a_level0_col3" class="col_heading level0 col3" >num_is_null</th>
#       <th id="T_ee49a_level0_col4" class="col_heading level0 col4" >num_mean_val</th>
#       <th id="T_ee49a_level0_col5" class="col_heading level0 col5" >num_min_val</th>
#       <th id="T_ee49a_level0_col6" class="col_heading level0 col6" >num_max_val</th>
#       <th id="T_ee49a_level0_col7" class="col_heading level0 col7" >num_unique_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee49a_level0_row0" class="row_heading level0 row0" >AcaYr</th>
#       <td id="T_ee49a_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_ee49a_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_ee49a_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_ee49a_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_ee49a_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_ee49a_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_ee49a_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_ee49a_row0_col7" class="data row0 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row1" class="row_heading level0 row1" >Residency</th>
#       <td id="T_ee49a_row1_col0" class="data row1 col0" >0.0</td>
#       <td id="T_ee49a_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_ee49a_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_ee49a_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_ee49a_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_ee49a_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_ee49a_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_ee49a_row1_col7" class="data row1 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row2" class="row_heading level0 row2" >Entry.Type</th>
#       <td id="T_ee49a_row2_col0" class="data row2 col0" >0.0</td>
#       <td id="T_ee49a_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_ee49a_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_ee49a_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_ee49a_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_ee49a_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_ee49a_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_ee49a_row2_col7" class="data row2 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row3" class="row_heading level0 row3" >DatePost</th>
#       <td id="T_ee49a_row3_col0" class="data row3 col0" >0.0</td>
#       <td id="T_ee49a_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_ee49a_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_ee49a_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_ee49a_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_ee49a_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_ee49a_row3_col6" class="data row3 col6" >0.0</td>
#       <td id="T_ee49a_row3_col7" class="data row3 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row4" class="row_heading level0 row4" >semester</th>
#       <td id="T_ee49a_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_ee49a_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_ee49a_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_ee49a_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_ee49a_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_ee49a_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_ee49a_row4_col6" class="data row4 col6" >0.0</td>
#       <td id="T_ee49a_row4_col7" class="data row4 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row5" class="row_heading level0 row5" >Residency Fee Desc</th>
#       <td id="T_ee49a_row5_col0" class="data row5 col0" >0.0</td>
#       <td id="T_ee49a_row5_col1" class="data row5 col1" >0.0</td>
#       <td id="T_ee49a_row5_col2" class="data row5 col2" >0.0</td>
#       <td id="T_ee49a_row5_col3" class="data row5 col3" >0.0</td>
#       <td id="T_ee49a_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_ee49a_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_ee49a_row5_col6" class="data row5 col6" >0.0</td>
#       <td id="T_ee49a_row5_col7" class="data row5 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row6" class="row_heading level0 row6" >Derived Residency Desc</th>
#       <td id="T_ee49a_row6_col0" class="data row6 col0" >0.0</td>
#       <td id="T_ee49a_row6_col1" class="data row6 col1" >0.0</td>
#       <td id="T_ee49a_row6_col2" class="data row6 col2" >0.0</td>
#       <td id="T_ee49a_row6_col3" class="data row6 col3" >0.0</td>
#       <td id="T_ee49a_row6_col4" class="data row6 col4" >0.0</td>
#       <td id="T_ee49a_row6_col5" class="data row6 col5" >0.0</td>
#       <td id="T_ee49a_row6_col6" class="data row6 col6" >0.0</td>
#       <td id="T_ee49a_row6_col7" class="data row6 col7" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ee49a_level0_row7" class="row_heading level0 row7" >Applicant Derived Residency</th>

# %%
assess_data(ugradenroll, 'turquoise')
# Out:
# <style type="text/css">
# #T_253ea_row0_col0, #T_253ea_row1_col0, #T_253ea_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, turquoise 9.1%, transparent 9.1%);
# }
# #T_253ea_row0_col1, #T_253ea_row0_col2, #T_253ea_row1_col1, #T_253ea_row1_col2, #T_253ea_row2_col1, #T_253ea_row2_col2, #T_253ea_row3_col1, #T_253ea_row3_col2, #T_253ea_row4_col1, #T_253ea_row4_col2, #T_253ea_row5_col1, #T_253ea_row5_col2, #T_253ea_row6_col1, #T_253ea_row6_col2, #T_253ea_row7_col1, #T_253ea_row7_col2 {
#   width: 10em;
# }
# #T_253ea_row2_col0, #T_253ea_row3_col0, #T_253ea_row5_col0, #T_253ea_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, turquoise 22.7%, transparent 22.7%);
# }
# #T_253ea_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, turquoise 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_253ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_253ea_level0_col0" class="col_heading level0 col0" >str_is_null</th>
#       <th id="T_253ea_level0_col1" class="col_heading level0 col1" >str_spaces</th>
#       <th id="T_253ea_level0_col2" class="col_heading level0 col2" >str_empty_string</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_253ea_level0_row0" class="row_heading level0 row0" >Week</th>
#       <td id="T_253ea_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_253ea_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_253ea_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row1" class="row_heading level0 row1" >2019 Fall NR Fee Payer</th>
#       <td id="T_253ea_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_253ea_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_253ea_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row2" class="row_heading level0 row2" >2020 Fall NR Fee Payer</th>
#       <td id="T_253ea_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_253ea_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_253ea_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row3" class="row_heading level0 row3" >2020 % of 2019</th>
#       <td id="T_253ea_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_253ea_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_253ea_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row4" class="row_heading level0 row4" >2019 Fall Resident</th>
#       <td id="T_253ea_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_253ea_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_253ea_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row5" class="row_heading level0 row5" >2020 Fall Resident</th>
#       <td id="T_253ea_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_253ea_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_253ea_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row6" class="row_heading level0 row6" >2020 % of 2019.1</th>
#       <td id="T_253ea_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_253ea_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_253ea_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_253ea_level0_row7" class="row_heading level0 row7" >milestone</th>
#       <td id="T_253ea_row7_col0" class="data row7 col0" >22</td>
#       <td id="T_253ea_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_253ea_row7_col2" class="data row7 col2" >0</td>
#     </tr>
#   </tbody>
# </table>
